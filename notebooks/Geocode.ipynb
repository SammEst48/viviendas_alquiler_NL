# %%
import pandas as pd
import googlemaps

from geopy.exc import GeocoderTimedOut

# %%
departamentos = pd.read_csv('/Users/samanthaestudillo/Documents/Notebooks/Anuncios de alquiler/Scraping/departamentos_scrap.csv')
casas1 = pd.read_csv('/Users/samanthaestudillo/Documents/Notebooks/Anuncios de alquiler/Scraping/casas_scrap.csv')

# %%
departamentos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Precio           600 non-null    object
#  1   Dirección        600 non-null    object
#  2   Ubicación        600 non-null    object
#  3   Características  600 non-null    object
#  4   Descripción      600 non-null    object
#  5   Latitud          600 non-null    float64
#  6   Longitud         600 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 32.9+ KB

# %%
gmaps = googlemaps.Client(key='AIzaSyCqbs3TR8cR0VBf2tBTAUQMnXuo1sji7WQ')

def obtener_latitud_longitud(ubicacion):
    try:
        geocode_result = gmaps.geocode(ubicacion)
        if geocode_result:
            return geocode_result[0]['geometry']['location']['lat'], geocode_result[0]['geometry']['location']['lng']
        else:
            return None, None
    except Exception as e:
        print(f"Error al geocodificar {ubicacion}: {e}")
        return None, None

# Obtener latitud y longitud para cada ubicación
departamentos['Latitud'], departamentos['Longitud'] = zip(*departamentos['Ubicación'].apply(obtener_latitud_longitud))

# %%
departamentos.head()
# Out:
#                          Precio  \
# 0  Departamentos desdeMN 24,100
# 1  Departamentos desdeMN 15,150
# 2                     MN 38,000
# 3                     MN 75,000
# 4                    MN 140,000
#
#                                            Dirección  \
# 0  Av. Revolución #2703, Col. Ladrillera, Monterr...
# 1                         Melchor Ocampo 380, Centro
# 2                                      No disponible
# 3                                      No disponible
# 4                                      No disponible
#
#                                      Ubicación  \
# 0                        Ladrillera, Monterrey
# 1                            Centro, Monterrey
# 2               Vía Cordillera, Santa Catarina
# 3  Valle del Campestre, San Pedro Garza García
# 4  Valle del Campestre, San Pedro Garza García
#
#                     Características  \
# 0                 204 un.1 a 3 rec.
# 1                 236 un.1 a 3 rec.
# 2   88 m² tot.2 rec.2 baños2 estac.
# ...

# %%
casas1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Precio           600 non-null    object
#  1   Dirección        600 non-null    object
#  2   Ubicación        600 non-null    object
#  3   Características  600 non-null    object
#  4   Descripción      600 non-null    object
# dtypes: object(5)
# memory usage: 23.6+ KB

# %%
gmaps = googlemaps.Client(key='AIzaSyCqbs3TR8cR0VBf2tBTAUQMnXuo1sji7WQ')

def obtener_latitud_longitud(ubicacion):
    try:
        geocode_result = gmaps.geocode(ubicacion)
        if geocode_result:
            return geocode_result[0]['geometry']['location']['lat'], geocode_result[0]['geometry']['location']['lng']
        else:
            return None, None
    except Exception as e:
        print(f"Error al geocodificar {ubicacion}: {e}")
        return None, None

# Obtener latitud y longitud para cada ubicación
casas1['Latitud'], casas1['Longitud'] = zip(*casas1['Ubicación'].apply(obtener_latitud_longitud))

# %%
casas1.head()
# Out:
#         Precio      Dirección                                      Ubicación  \
# 0   MN 200,000  No disponible              Del Valle, San Pedro Garza García
# 1   MN 165,000  No disponible  San Agustin Campestre, San Pedro Garza García
# 2    MN 60,000  No disponible            Palo Blanco, San Pedro Garza García
# 3  MN 39,0008%  No disponible     Hacienda Del Valle, San Pedro Garza García
# 4    MN 65,000  No disponible      Fuentes del Valle, San Pedro Garza García
#
#                     Características  \
# 0  400 m² tot.4 rec.5 baños3 estac.
# 1         650 m² tot.3 rec.3 estac.
# 2  270 m² tot.3 rec.3 baños2 estac.
# 3  150 m² tot.3 rec.2 baños2 estac.
# 4  300 m² tot.4 rec.3 baños3 estac.
#
#                                          Descripción    Latitud    Longitud
# 0  Extraordinaria y Lujosa propiedad totalmente n...  25.656484 -100.369440
# 1  Preciosa Residencia muy iluminada con acabados...  25.633717 -100.339966
# ...

# %%
departamentos.to_csv('depas_geocode.csv', index=False)
casas1.to_csv('casas_geocode.csv', index=False)
